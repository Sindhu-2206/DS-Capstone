# %%
# !git clone https://github.com/tmllab/2024_NeurIPS_CSGN.git
# !cd 2024_NeurIPS_CSGN && pip install -r requirements.txt
# Out:
# Cloning into '2024_NeurIPS_CSGN'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 27 (delta 13), reused 24 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 28.31 KiB | 4.72 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 2.7 MB/s eta 0:00:00
# ...

# %%
import os

# Create configs folder if it doesn't exist
os.makedirs('configs', exist_ok=True)

# Define your configuration (sample)
config = {
    'batch_size': 32,
    'learning_rate': 0.001,
    'epochs': 20,
    'dataset_path': 'data/supply_chain_data.csv',
}

# Save to a config file (JSON example)
import json
with open('configs/model_config.json', 'w') as f:
    json.dump(config, f, indent=4)

# %%
# !pip install torchnet
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 29.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.7 MB/s eta 0:00:00
# ...

# %%
# Assuming the training script is named Train_webvision.py
# !python /content/2024_NeurIPS_CSGN/Train_webvision.py --config /content/configs/model_config.json
# Out:
# usage: Train_webvision.py [-h] [--batch_size BATCH_SIZE] [--lr LR]
#                           [--vae_lr VAE_LR] [--alpha ALPHA]
#                           [--lambda_u LAMBDA_U] [--p_threshold P_THRESHOLD]
#                           [--T T] [--num_epochs NUM_EPOCHS] [--id ID]
#                           [--seed SEED] [--gpuid GPUID]
#                           [--num_class NUM_CLASS] [--lambda_elbo LAMBDA_ELBO]
#                           [--lambda_M LAMBDA_M] [--z_dim Z_DIM]
#                           [--data_path DATA_PATH]
# Train_webvision.py: error: unrecognized arguments: --config /content/configs/model_config.json

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fake sample data – replace with your actual predictions
actual = np.array([50, 55, 60, 65, 70])
predictions = np.array([48, 56, 62, 66, 69])

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(actual, label='Actual Production', marker='o')
plt.plot(predictions, label='Predicted Production', marker='x')
plt.xlabel('Sample Index')
plt.ylabel('Production Value')
plt.title('Predicted vs Actual Production')
plt.legend()

# Save the figure
plt.savefig('production_comparison.png')

# Display the plot (for notebooks)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Example data (replace with actual model output)
actual = np.array([10, 20, 30, 40, 50])
predictions = np.array([11, 19, 32, 38, 48])

# Calculate metrics
mae = mean_absolute_error(actual, predictions)
rmse = np.sqrt(mean_squared_error(actual, predictions))
r2 = r2_score(actual, predictions)

# Print metrics
print(f'Mean Absolute Error (MAE): {mae:.4f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.4f}')
print(f'R² Score: {r2:.4f}')
# Out:
# Mean Absolute Error (MAE): 1.6000
# Root Mean Squared Error (RMSE): 1.6733
# R² Score: 0.9860
