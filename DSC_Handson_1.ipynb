# %% [markdown]
# <a href="https://colab.research.google.com/github/Sindhu-2206/DS-Capstone/blob/main/DSC_Handson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install transformers

# %%
from transformers import pipeline
summarizer = pipeline("summarization")
text = "This is Sindhu Mukkara"
summary = summarizer(text, max_length=50, min_length=25,
do_sample=False)
print(summary)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# Your max_length is set to 50, but your input_length is only 9. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
# [{'summary_text': ' Sindhu Mukkara is a former Olympic gold medalist and Olympic champion . She has been married to Olympic gold medallist and world No. 1 . She is a pro-sport athlete in the sport of the year .'}]

# %%
from google.colab import files
uploaded = files.upload()  # Upload your file

for filename in uploaded.keys():
    print(f"Processing file: {filename}")
    with open(filename, 'r') as file:
        text = file.read()
        summary = summarizer(text, max_length=50, min_length=25, do_sample=False)
        print(f"Summary: {summary}")
# Out:
#      <input type="file" id="files-4a6863e0-5e78-4faa-861f-d8273992b19c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a6863e0-5e78-4faa-861f-d8273992b19c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
classifier = pipeline("sentiment-analysis")
result = classifier("I like playing sports")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9994208812713623}]

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe = pipeline("text-generation", model="microsoft/phi-4", trust_remote_code=True)
pipe(messages)
# Out:
# config.json:   0%|          | 0.00/820 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.4k [00:00<?, ?B/s]
# ...
# model-00001-of-00006.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00002-of-00006.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00006.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00004-of-00006.safetensors:   0%|          | 0.00/4.77G [00:00<?, ?B/s]
# model-00005-of-00006.safetensors:   0%|          | 0.00/4.77G [00:00<?, ?B/s]
# model-00006-of-00006.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-4", trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained("microsoft/phi-4", trust_remote_code=True)
